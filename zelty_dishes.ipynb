# %%
import pandas as pd
from zelty_orders import dishes_df

# %%
dishes_df
# Out:
#                                                dishes  errno
# 0   {'id': 1470596, 'remote_id': None, 'id_restaur...      0
# 1   {'id': 1470597, 'remote_id': None, 'id_restaur...      0
# 2   {'id': 1470598, 'remote_id': None, 'id_restaur...      0
# 3   {'id': 1470599, 'remote_id': None, 'id_restaur...      0
# 4   {'id': 1470600, 'remote_id': None, 'id_restaur...      0
# 5   {'id': 1470601, 'remote_id': None, 'id_restaur...      0
# 6   {'id': 1470602, 'remote_id': None, 'id_restaur...      0
# 7   {'id': 1470603, 'remote_id': None, 'id_restaur...      0
# 8   {'id': 1470604, 'remote_id': None, 'id_restaur...      0
# 9   {'id': 1470605, 'remote_id': None, 'id_restaur...      0
# 10  {'id': 1470606, 'remote_id': None, 'id_restaur...      0
# 11  {'id': 1470607, 'remote_id': None, 'id_restaur...      0
# 12  {'id': 1470608, 'remote_id': None, 'id_restaur...      0
# 13  {'id': 1470609, 'remote_id': None, 'id_restaur...      0
# ...
