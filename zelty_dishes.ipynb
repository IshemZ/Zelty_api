# %%
import pandas as pd
from zelty_orders import dishes

# %%
dishes
# Out:
# {'dishes': [{'id': 1470596,
#    'remote_id': None,
#    'id_restaurant': None,
#    'sku': None,
#    'name': '🍔 Le classique',
#    'description': "Bœuf de Normandie haché maison ou végétarien, cheddar, sauce crème, chutney d'oignons rouges, cornichons, pain du boulanger.",
#    'image': 'https://media.zelty.fr/images/2362/6402/35091.jpg',
#    'thumb': 'https://media.zelty.fr/thumb/300x300/images/2362/6402/35091.jpg',
#    'price': 1300,
#    'price_togo': None,
#    'price_delivery': None,
#    'happy_price': None,
#    'cost_price': None,
#    'tva': 1000,
#    'tvat': None,
#    'tvad': None,
#    'tax': 1000,
#    'tax_takeaway': None,
#    'tax_delivery': None,
#    'tags': [369602],
#    'options': [229305, 229304],
#    'id_fabrication_place': 15568,
#    'fab_name': None,
#    'color': None,
#    'loyalty_points': 0,
#    'loyalty_points_discount': None,
#    'earn_loyalty': 0,
#    'price_to_define': False,
#    'weight_for_price': None,
#    'disable': False,
# ...

# %%
from pprint import pprint
pprint(dishes)
# Out:
# {'dishes': [{'color': None,
#              'cost_price': None,
#              'description': 'Bœuf de Normandie haché maison ou végétarien, '
#                             "cheddar, sauce crème, chutney d'oignons rouges, "
#                             'cornichons, pain du boulanger.',
#              'disable': False,
#              'disable_after': None,
#              'disable_before': None,
#              'disable_delivery': False,
#              'disable_takeaway': False,
#              'earn_loyalty': 0,
#              'fab_name': None,
#              'happy_price': None,
#              'id': 1470596,
#              'id_fabrication_place': 15568,
#              'id_restaurant': None,
#              'image': 'https://media.zelty.fr/images/2362/6402/35091.jpg',
#              'loyalty_points': 0,
#              'loyalty_points_discount': None,
#              'meta': {},
#              'name': '🍔 Le classique',
#              'o': 0,
#              'options': [229305, 229304],
# ...
